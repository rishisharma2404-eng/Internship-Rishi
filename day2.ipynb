# %%
name = input("Enter Student Name: ")
student_class = input("Enter Class: ")

mark1 = int(input("Enter marks of Subject 1: "))
mark2 = int(input("Enter marks of Subject 2: "))
mark3 = int(input("Enter marks of Subject 3: "))
mark4 = int(input("Enter marks of Subject 4: "))
mark5 = int(input("Enter marks of Subject 5: "))

# Total Marks
total = mark1 + mark2 + mark3 + mark4 + mark5

# Percentage
percentage = total / 5

# Display Result
print("\n----- RESULT -----")
print("Student Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
# Out:
# ----- RESULT -----
# Student Name : rishi
# Class : 10
# Total Marks : 445
# Percentage : 89.0 %

# %%
# Input two strings

str1 = input("Enter First String: ")
str2 = input("Enter Second String: ")

# Concatenate strings
result = str1 + " " + str2

print("\nConcatenated String:", result)

# String Methods
print("\nLower Case:", result.lower())

print("Upper Case:", result.upper())

print("Title Case:", result.title())

print("Swap Case:", result.swapcase())

print("Capitalize:", result.capitalize())

print("Casefold:", result.casefold())

print("Center:", result.center(50, '*'))

print("Count of 'a':", result.count('a'))

print("Endswith 'a':", result.endswith('a'))

print("Find 'a':", result.find('a'))

print("Is Alphanumeric:", result.isalnum())

print("Is Digit:", result.isdigit())

print("Is Numeric:", result.isnumeric())

print("Is Space:", result.isspace())

print("Replace:", result.replace("a", "@"))
# Out:
# Concatenated String: rishi sharma  kumar
#
# Lower Case: rishi sharma  kumar
# Upper Case: RISHI SHARMA  KUMAR
# Title Case: Rishi Sharma  Kumar
# Swap Case: RISHI SHARMA  KUMAR
# Capitalize: Rishi sharma  kumar
# Casefold: rishi sharma  kumar
# Center: ***************rishi sharma  kumar****************
# Count of 'a': 3
# Endswith 'a': False
# Find 'a': 8
# Is Alphanumeric: False
# Is Digit: False
# Is Numeric: False
# Is Space: False
# Replace: rishi sh@rm@  kum@r

# %%
# Assignment Operators Program

a = 10
print("Initial Value of a:", a)

# += Operator
a += 5
print("After += :", a)

# -= Operator
a -= 3
print("After -= :", a)

# *= Operator
a *= 2
print("After *= :", a)

# /= Operator
a /= 4
print("After /= :", a)

# %= Operator
a %= 3
print("After %= :", a)

# **= Operator
a **= 2
print("After **= :", a)

# //= Operator
a //= 2
print("After //= :", a)
# Out:
# Initial Value of a: 10
# After += : 15
# After -= : 12
# After *= : 24
# After /= : 6.0
# After %= : 0.0
# After **= : 0.0
# After //= : 0.0

# %%
# Student Result with Grade

name = input("Enter Student Name: ")
student_class = input("Enter Class: ")

mark1 = int(input("Enter marks of Subject 1: "))
mark2 = int(input("Enter marks of Subject 2: "))
mark3 = int(input("Enter marks of Subject 3: "))
mark4 = int(input("Enter marks of Subject 4: "))
mark5 = int(input("Enter marks of Subject 5: "))

# Calculate Total
total = mark1 + mark2 + mark3 + mark4 + mark5

# Calculate Percentage
percentage = total / 5

# Find Grade
if percentage >= 60:
    grade = 'A'

elif percentage >= 50 and percentage < 60:
    grade = 'B'

elif percentage >= 40 and percentage < 50:
    grade = 'C'

elif percentage >= 33 and percentage < 40:
    grade = 'D'

else:
    grade = 'Fail'

# Display Result
print("\n----- RESULT -----")
print("Student Name :", name)
print("Class :", student_class)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
print("Grade :", grade)
# Out:
# ----- RESULT -----
# Student Name : rishi
# Class : 10
# Total Marks : 445
# Percentage : 89.0 %
# Grade : A
